# %%
import pandas_datareader.data as reader
import yfinance as yf
import datetime as dt
import matplotlib.pyplot as plt

# %%
start = dt.date(2000,1,1)
end = dt.datetime.now()
stocks = ['AAPL']

# %%
df = yf.download(stocks, start=start, end=end)
df.head(5)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2000-01-03  0.936384  1.004464  0.907924  0.999442   0.844981  535796800
# 2000-01-04  0.966518  0.987723  0.903460  0.915179   0.773741  512377600
# 2000-01-05  0.926339  0.987165  0.919643  0.928571   0.785063  778321600
# 2000-01-06  0.947545  0.955357  0.848214  0.848214   0.717125  767972800
# 2000-01-07  0.861607  0.901786  0.852679  0.888393   0.751094  460734400

# %%
df = df["Adj Close"]
df.head()
# Out:
# Date
# 2000-01-03    0.844981
# 2000-01-04    0.773741
# 2000-01-05    0.785063
# 2000-01-06    0.717125
# 2000-01-07    0.751094
# Name: Adj Close, dtype: float64

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Get daily returns
daily_returns = df.pct_change()

# %%
daily_returns.head()
# Out:
# Date
# 2000-01-03         NaN
# 2000-01-04   -0.084310
# 2000-01-05    0.014633
# 2000-01-06   -0.086538
# 2000-01-07    0.047369
# Name: Adj Close, dtype: float64

# %%
daily_returns.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
start = dt.date(2000,1,1)
end = dt.datetime.now()
stocks = ['AAPL', 'MSFT']

df = yf.download(stocks, start=start, end=end)
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
df.head()
# Out:
# Price      Adj Close                Close                High           \
# Ticker          AAPL       MSFT      AAPL      MSFT      AAPL     MSFT
# Date
# 2000-01-03  0.844981  36.000629  0.999442  58.28125  1.004464  59.3125
# 2000-01-04  0.773741  34.784512  0.915179  56.31250  0.987723  58.5625
# 2000-01-05  0.785063  35.151276  0.928571  56.90625  0.987165  58.1875
# 2000-01-06  0.717125  33.973782  0.848214  55.00000  0.955357  56.9375
# 2000-01-07  0.751094  34.417759  0.888393  55.71875  0.901786  56.1250
#
# Price            Low                Open               Volume
# Ticker          AAPL      MSFT      AAPL      MSFT       AAPL      MSFT
# Date
# 2000-01-03  0.907924  56.00000  0.936384  58.68750  535796800  53228400
# 2000-01-04  0.903460  56.12500  0.966518  56.78125  512377600  54119000
# 2000-01-05  0.919643  54.68750  0.926339  55.56250  778321600  64059600
# 2000-01-06  0.848214  54.18750  0.947545  56.09375  767972800  54976600
# 2000-01-07  0.852679  53.65625  0.861607  54.31250  460734400  62013600

# %%
df = df["Adj Close"]
df.head()
# Out:
# Ticker          AAPL       MSFT
# Date
# 2000-01-03  0.844981  36.000629
# 2000-01-04  0.773741  34.784512
# 2000-01-05  0.785063  35.151276
# 2000-01-06  0.717125  33.973782
# 2000-01-07  0.751094  34.417759

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
daily_returns = df.pct_change()
daily_returns
# Out:
# Ticker          AAPL      MSFT
# Date
# 2000-01-03       NaN       NaN
# 2000-01-04 -0.084310 -0.033780
# 2000-01-05  0.014633  0.010544
# 2000-01-06 -0.086538 -0.033498
# 2000-01-07  0.047369  0.013068
# ...              ...       ...
# 2024-05-24  0.016588  0.007400
# 2024-05-28  0.000053  0.000372
# 2024-05-29  0.001579 -0.002672
# 2024-05-30  0.005255 -0.033786
# 2024-05-31  0.005019  0.001109
#
# [6142 rows x 2 columns]

# %%
daily_returns.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
daily_cum_returns = (daily_returns+1).cumprod()
daily_cum_returns.head()
# Out:
# Ticker          AAPL      MSFT
# Date
# 2000-01-03       NaN       NaN
# 2000-01-04  0.915690  0.966220
# 2000-01-05  0.929090  0.976408
# 2000-01-06  0.848688  0.943700
# 2000-01-07  0.888889  0.956032

# %%
daily_cum_returns.plot()
# Out:
# <Axes: xlabel='Date'>
